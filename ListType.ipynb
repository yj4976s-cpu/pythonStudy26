# %%
# 리스트란 표형식의 배열을 말한다.
# ids = ["kkw", "jhj","ksb"]
# pws = ["1234", "4321", "4567"]
# names = ["김기원", "임효정", "김수빈"]
# 리스트를 만들 때는 대괄호[] 로 감싸주고 쉼표, 로 구분한다.

# a = [] 빈 리스트를 생성한다. -> a = list()
# b = [1, 2, 3] 정수를 입력 할 수 있다. -> b[1] => 2
# c = [1, 2, 'kkw', 'lhk']와 같이 혼용하여 넣을 수 있다.
#     학년 반 이름    id  파이썬만 가능
# d = [1, 2, ['kkw', '1234']] 2차원 리스트
#               0     1
#      0  1       2
# d 변수에서 kkw를 가져오고 싶으면?? d[2][0]
# f = [1, 2, ['kkw', '1234', ['파이썬', '자바']]]
#                                0      1
#             0       1            2
#      0   1   2
# f 변수에서 파이썬을 가지고 오고 싶으면? f[2][2][0]

# %%
# 리스트의 인덱싱 -> 문자열 인덱싱과 같다.
a = [1, 2, 3]
print(a)
# Out:
# [1, 2, 3]

# %%
a
# Out:
# [1, 2, 3]

# %%
type(a)
# Out:
# list

# %%
a[0]
# Out:
# 1

# %%
a[0]+a[2]
# Out:
# 4

# %%
a[-1]
# Out:
# 3

# %%
b = [1, 2, 3,['a','b','c']] # 2차원 리스트
b[3][2]
# Out:
# 'c'

# %%
b[-1][1]
# Out:
# 'b'

# %%
# 리스트의 슬라이싱 -> 문자열의 슬라이싱과 같다.
c = [1, 2, 3, 4, 5, 6]
c[0:2] # 주의사항 마지막 숫자 -1 인덱스 값이 나온다.
# Out:
# [1, 2]

# %%
c[:2] # : 앞에 생략하면 처음값
# Out:
# [1, 2]

# %%
c[2:] # 뒤에 값을 생략하면 끝까지!
# Out:
# [3, 4, 5, 6]

# %%
# 리스트 더하기
d = [1, 2, 3]
e = [4, 5, 6]
f = d + e
print(f)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 리스트 곱하기
g = e*2
print(g)
# Out:
# [4, 5, 6, 4, 5, 6]

# %%
# 리스트 길이 구하기
len(g)
# Out:
# 6

# %%
# 초보자가 범하기 쉬운 리스트 연산 오류
h = [1, 2, 3]
# h[2]+"hi" # 3hi 이렇게 하면 안된다.
str(h[2])+"hi"
# Out:
# '3hi'

# %%
# 리스트에 C R U D 기법을 적용해보자.
# CREATE -> 생성, 추가, 삽입 .append()
# READ -> 전체리스트보기, 1개 자료 보기 .index()
# UPDATE -> 자료 수정 passwords[3] = "4486"
# DELETE -> 자료 삭제 del passwords[3] .remove(3) .pop(3)

# %%
# 리스트에 자료를 추가해보자!!
ids = ["kkw", "lhj", "ksb"] # 회원 id
ids.append("MBC")
print(ids)
# Out:
# ['kkw', 'lhj', 'ksb', 'MBC']

# %%
passwords = ["1234", "4321", "4567"]
passwords.append("8888")
print(passwords)
# Out:
# ['1234', '4321', '4567', '8888']

# %%
# 리스트에 있는 값 가져오기
ids.index("MBC")
# Out:
# 3

# %%
# MBC ID에 인덱스를 알아봐 패스워드의 값을 찾아온다.
passwords[3]
# Out:
# '8888'

# %%
# 알아온 password 값을 4486으로 수정해본다.
passwords[3] = "4486"
print(passwords)
# Out:
# ['1234', '4321', '4567', '4486']

# %%
# 3번째 인덱스에 암호를 삭제해본다.
passwords.remove("4486")
print(passwords)
# Out:
# ['1234', '4321', '4567']

# %%
# pop은 삭제되는 내용을 출력하고 삭제한다.
# passwords.pop() -> 맨 마지막 자료를 삭제
# passwords.pop(2) -> 2 인덱스를 삭제한다.
passwords.pop(2)
# Out:
# '4567'

# %%
print(passwords)
# Out:
# ['1234', '4321']

# %%
a = [1, 2, 3, ['a','b','c'], 4, 5]
a[2:5]
a[3][:2]
# Out:
# ['a', 'b']
